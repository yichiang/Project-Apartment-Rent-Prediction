# %%
# Python 2 & 3 Compatibility
from __future__ import print_function, division

# Necessary imports
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
import os
import pickle
# %matplotlib inline
from datetime import datetime
from dateutil.parser import parse

# %%
with open("all_data.pkl", 'rb') as picklefile: 
    merge_housing = pickle.load(picklefile)
merge_housing.head()
# Out:
#   BedSize  Year Month  Apartment_rent Shift_Year Shift_Month  \
# 0  Studio  2011    03          1097.5       2011          03
# 1  Studio  2011    04          1095.0       2011          04
# 2  Studio  2011    05          1025.0       2011          05
# 3  Studio  2011    06           995.0       2011          06
# 4  Studio  2011    07          1000.0       2011          07
#
#    Zillow_Housing_price Search_Count_SeattleRent Search_Count_SeattleHousing  \
# 0              382800.0                       37                          33
# 1              373500.0                       33                          22
# 2              368400.0                       33                          25
# 3              359300.0                       27                          23
# 4              365300.0                       36                          25
#
#   Search_Count_seattleApartment    ...      New Listings Mom New Listings Yoy  \
# 0                            24    ...                   NaN              NaN
# 1                            16    ...                   NaN              NaN
# 2                            21    ...                   NaN              NaN
# 3                            19    ...                   NaN              NaN
# 4                            22    ...                67.50%          -16.20%
#
#   Number of Records Price Drops Price Drops Mom Price Drops Yoy  \
# 0               NaN         NaN             NaN             NaN
# 1               NaN         NaN             NaN             NaN
# 2               NaN         NaN             NaN             NaN
# 3               NaN         NaN             NaN             NaN
# 4               1.0    0.286394        0.082724       -0.006008
#
#   Sold Above List Sold Above List Mom Sold Above List Yoy       Date
# 0             NaN                 NaN                 NaN 2011-03-01
# 1             NaN                 NaN                 NaN 2011-04-01
# 2             NaN                 NaN                 NaN 2011-05-01
# 3             NaN                 NaN                 NaN 2011-06-01
# 4        0.162996           -0.008754            0.059369 2011-07-01
#
# [5 rows x 48 columns]

# %%
sns.distplot(merge_housing.Apartment_rent)

# %%
plt.subplots(figsize=(15,10))
sns.swarmplot(x=merge_housing['BedSize'], y=merge_housing['Apartment_rent'], data=merge_housing)

# %%
merge_housing.plot.line(x='Year', y='Zillow_Housing_price')

# %%
sns.distplot(merge_housing.Zillow_Housing_price.dropna())

# %%
# Let's now look at Distribution of Age and Survived
# Now look at survived data
g = sns.FacetGrid(merge_housing, col='BedSize')
g.map(plt.scatter, 'Year', "Apartment_rent")

# %%
merge_housing['Year'].value_counts()
# Out:
# 2017    71
# 2016    46
# 2013    36
# 2015    36
# 2014    36
# 2012    36
# 2011    29
# 2018    12
# Name: Year, dtype: int64

# %%
merge_housing['BedSize'].value_counts()
# Out:
# 1Bedroom          86
# Studio            84
# 3Bedroom          81
# 5BedroomOrMore    20
# 2Bedroom          18
# 4Bedroom          13
# Name: BedSize, dtype: int64

# %%
#df_apartment_bedSize = pd.get_dummies(merge_housing['BedSize'])
#zillow_apartment_df_new = pd.concat([merge_housing, df_apartment_bedSize], axis=1)

# %%
# Get Average
zillow_apartment_grouped_df = merge_housing
zillow_apartment_grouped_df.groupby(['BedSize', 'Year', 'Month'], as_index=False)['Apartment_rent'].agg('mean')
zillow_apartment_grouped_df.head()
# Out:
#   BedSize  Year Month  Apartment_rent Shift_Year Shift_Month  \
# 0  Studio  2011    03          1097.5       2011          03
# 1  Studio  2011    04          1095.0       2011          04
# 2  Studio  2011    05          1025.0       2011          05
# 3  Studio  2011    06           995.0       2011          06
# 4  Studio  2011    07          1000.0       2011          07
#
#    Zillow_Housing_price Search_Count_SeattleRent Search_Count_SeattleHousing  \
# 0              382800.0                       37                          33
# 1              373500.0                       33                          22
# 2              368400.0                       33                          25
# 3              359300.0                       27                          23
# 4              365300.0                       36                          25
#
#   Search_Count_seattleApartment    ...      New Listings Mom New Listings Yoy  \
# 0                            24    ...                   NaN              NaN
# 1                            16    ...                   NaN              NaN
# 2                            21    ...                   NaN              NaN
# 3                            19    ...                   NaN              NaN
# 4                            22    ...                67.50%          -16.20%
#
#   Number of Records Price Drops Price Drops Mom Price Drops Yoy  \
# 0               NaN         NaN             NaN             NaN
# 1               NaN         NaN             NaN             NaN
# 2               NaN         NaN             NaN             NaN
# 3               NaN         NaN             NaN             NaN
# 4               1.0    0.286394        0.082724       -0.006008
#
#   Sold Above List Sold Above List Mom Sold Above List Yoy       Date
# 0             NaN                 NaN                 NaN 2011-03-01
# 1             NaN                 NaN                 NaN 2011-04-01
# 2             NaN                 NaN                 NaN 2011-05-01
# 3             NaN                 NaN                 NaN 2011-06-01
# 4        0.162996           -0.008754            0.059369 2011-07-01
#
# [5 rows x 48 columns]

# %%
studio_df = zillow_apartment_grouped_df.loc[zillow_apartment_grouped_df['BedSize'] == 'Studio']
oneBed_df = zillow_apartment_grouped_df.loc[zillow_apartment_grouped_df['BedSize'] == '1Bedroom']
twoBed_df = zillow_apartment_grouped_df.loc[zillow_apartment_grouped_df['BedSize'] == '2Bedroom']

# %%
merge_housing['Apartment_rent'].hist()

# %%
studio_df['Year'].value_counts()
# Out:
# 2015    12
# 2014    12
# 2017    12
# 2013    12
# 2016    12
# 2012    12
# 2011    10
# 2018     2
# Name: Year, dtype: int64

# %%
studio_df.plot.line(x='Year', y='Apartment_rent')

# %%
studio_df[studio_df.Apartment_rent < 1200]
# Out:
#    BedSize  Year Month  Apartment_rent Shift_Year Shift_Month  \
# 0   Studio  2011    03          1097.5       2011          03
# 1   Studio  2011    04          1095.0       2011          04
# 2   Studio  2011    05          1025.0       2011          05
# 3   Studio  2011    06           995.0       2011          06
# 4   Studio  2011    07          1000.0       2011          07
# 5   Studio  2011    08          1000.0       2011          08
# 6   Studio  2011    09          1075.0       2011          09
# 7   Studio  2011    10           995.0       2011          10
# 8   Studio  2011    11           865.0       2011          11
# 9   Studio  2011    12           902.0       2011          12
# 10  Studio  2012    01           897.0       2012          01
# 11  Studio  2012    02           900.0       2012          02
# 12  Studio  2012    03          1025.0       2012          03
# 13  Studio  2012    04          1060.0       2012          04
# 14  Studio  2012    05          1060.0       2012          05
# 15  Studio  2012    06          1072.5       2012          06
# 16  Studio  2012    07          1080.0       2012          07
# 17  Studio  2012    08          1095.0       2012          08
# 18  Studio  2012    09          1150.0       2012          09
# 19  Studio  2012    10          1195.0       2012          10
# 20  Studio  2012    11          1195.0       2012          11
# 21  Studio  2012    12          1150.0       2012          12
# 22  Studio  2013    01          1140.0       2013          01
# 23  Studio  2013    02          1147.5       2013          02
# 26  Studio  2013    05          1140.0       2013          05
# 27  Studio  2013    06          1150.0       2013          06
# 28  Studio  2013    07          1188.0       2013          07
# 29  Studio  2013    08          1199.0       2013          08
# 31  Studio  2013    10          1180.0       2013          10
# 36  Studio  2014    03          1195.0       2014          03
#
#     Zillow_Housing_price Search_Count_SeattleRent Search_Count_SeattleHousing  \
# 0               382800.0                       37                          33
# 1               373500.0                       33                          22
# 2               368400.0                       33                          25
# 3               359300.0                       27                          23
# 4               365300.0                       36                          25
# 5               367900.0                       36                          24
# 6               381900.0                       38                          28
# 7               393600.0                       38                          29
# 8               400700.0                       46                          26
# 9               395100.0                       45                          29
# 10              390600.0                       50                          31
# 11              392100.0                       47                          25
# 12              400800.0                       37                          26
# 13              400300.0                       27                          25
# 14              406000.0                       30                          21
# 15              405800.0                       31                          23
# 16              406600.0                       39                          25
# 17              412600.0                       37                          35
# 18              418300.0                       38                          27
# 19              423300.0                       39                          31
# 20              419900.0                       39                          28
# 21              415600.0                       43                          30
# 22              420000.0                       46                          23
# 23              421300.0                       43                          29
# 26              427300.0                       30                          20
# 27              427200.0                       29                          21
# 28              430600.0                       40                          25
# 29              435300.0                       37                          23
# 31              424600.0                       40                          27
# 36              444900.0                       41                          27
#
#    Search_Count_seattleApartment    ...      New Listings Mom  \
# 0                             24    ...                   NaN
# 1                             16    ...                   NaN
# 2                             21    ...                   NaN
# 3                             19    ...                   NaN
# 4                             22    ...                67.50%
# 5                             22    ...                20.30%
# 6                             22    ...                28.60%
# 7                             28    ...                 3.70%
# 8                             25    ...                 3.90%
# 9                             26    ...                -6.30%
# 10                            30    ...               -10.00%
# 11                            24    ...                -5.90%
# 12                            21    ...                19.50%
# 13                            18    ...               -23.10%
# 14                            16    ...               -29.40%
# 15                            22    ...               -37.90%
# 16                            26    ...               108.00%
# 17                            19    ...                25.10%
# 18                            24    ...                21.10%
# 19                            25    ...                11.50%
# 20                            24    ...                16.80%
# 21                            29    ...                -3.10%
# 22                            26    ...               -10.70%
# 23                            25    ...                -5.20%
# 26                            19    ...               -38.90%
# 27                            22    ...               -38.30%
# 28                            22    ...               122.20%
# 29                            24    ...                 2.30%
# 31                            26    ...                12.70%
# 36                            27    ...                17.70%
#
#    New Listings Yoy Number of Records Price Drops Price Drops Mom  \
# 0               NaN               NaN         NaN             NaN
# 1               NaN               NaN         NaN             NaN
# 2               NaN               NaN         NaN             NaN
# 3               NaN               NaN         NaN             NaN
# 4           -16.20%               1.0    0.286394        0.082724
# 5           -11.20%               1.0    0.289133        0.002739
# 6            -6.40%               1.0    0.282218       -0.006915
# 7            -8.10%               1.0    0.262083       -0.020135
# 8             4.80%               1.0    0.259186       -0.002897
# 9            -6.80%               1.0    0.279230        0.020045
# 10            2.60%               1.0    0.266467       -0.012763
# 11           -1.80%               1.0    0.285342        0.018875
# 12           13.10%               1.0    0.281732       -0.003609
# 13            9.60%               1.0    0.348890        0.067158
# 14           -4.30%               1.0    0.246684       -0.102206
# 15          -10.70%               1.0    0.141647       -0.105037
# 16           10.80%               1.0    0.212714        0.071067
# 17           15.20%               1.0    0.192969       -0.019745
# 18            8.60%               1.0    0.245151        0.052183
# 19           16.80%               1.0    0.241528       -0.003623
# 20           31.30%               1.0    0.264617        0.023089
# 21           35.70%               1.0    0.272079        0.007462
# 22           34.70%               1.0    0.295491        0.023412
# 23           35.70%               1.0    0.290030       -0.005461
# 26            6.80%               1.0    0.294695       -0.057995
# 27            6.00%               1.0    0.210196       -0.084499
# 28           13.20%               1.0    0.249802        0.039606
# 29           -7.40%               1.0    0.237329       -0.012473
# 31            0.30%               1.0    0.267216        0.004972
# 36            1.50%               1.0    0.330465        0.046292
#
#    Price Drops Yoy Sold Above List Sold Above List Mom Sold Above List Yoy  \
# 0              NaN             NaN                 NaN                 NaN
# 1              NaN             NaN                 NaN                 NaN
# 2              NaN             NaN                 NaN                 NaN
# 3              NaN             NaN                 NaN                 NaN
# 4        -0.006008        0.162996           -0.008754            0.059369
# 5         0.019233        0.167315            0.004320            0.038875
# 6        -0.040034        0.255848            0.088533            0.130313
# 7        -0.028809        0.270305            0.014457            0.104366
# 8        -0.039458        0.292494            0.022190            0.136814
# 9        -0.042252        0.303323            0.010828            0.144919
# 10       -0.049207        0.296429           -0.006894            0.118817
# 11       -0.030448        0.279461           -0.016967            0.148671
# 12       -0.036479        0.311429            0.031967            0.160427
# 13        0.015557        0.260355           -0.051074            0.074194
# 14       -0.062926        0.275457            0.015102            0.082237
# 15       -0.062022        0.267143           -0.008314            0.095393
# 16       -0.073680        0.244318           -0.022825            0.081323
# 17       -0.096164        0.339223            0.094904            0.171907
# 18       -0.037067        0.363415            0.024192            0.107567
# 19       -0.020554        0.409664            0.046249            0.139359
# 20        0.005432        0.452999            0.043335            0.160505
# 21       -0.007151        0.431102           -0.021897            0.127780
# 22        0.029024        0.424084           -0.007019            0.127655
# 23        0.004689        0.364376           -0.059708            0.084915
# 26        0.048011        0.282185           -0.053840            0.006728
# 27        0.068549        0.255348           -0.026837           -0.011795
# 28        0.037088        0.277174            0.021826            0.032856
# 29        0.044360        0.331746            0.054572           -0.007477
# 31        0.025687        0.453044            0.048254            0.043381
# 36       -0.004673        0.318280           -0.029891           -0.019923
#
#          Date
# 0  2011-03-01
# 1  2011-04-01
# 2  2011-05-01
# 3  2011-06-01
# 4  2011-07-01
# 5  2011-08-01
# 6  2011-09-01
# 7  2011-10-01
# 8  2011-11-01
# 9  2011-12-01
# 10 2012-01-01
# 11 2012-02-01
# 12 2012-03-01
# 13 2012-04-01
# 14 2012-05-01
# 15 2012-06-01
# 16 2012-07-01
# 17 2012-08-01
# 18 2012-09-01
# 19 2012-10-01
# 20 2012-11-01
# 21 2012-12-01
# 22 2013-01-01
# 23 2013-02-01
# 26 2013-05-01
# 27 2013-06-01
# 28 2013-07-01
# 29 2013-08-01
# 31 2013-10-01
# 36 2014-03-01
#
# [30 rows x 48 columns]

# %%
studio_df['Apartment_rent'].hist()

# %%
oneBed_df.plot.line(x='Year', y='Apartment_rent')

# %%
oneBed_df['Apartment_rent'].hist()

# %%
oneBed_df['log_price'] = np.log(oneBed_df['Apartment_rent'])
oneBed_df.plot.line(x='Year', y='log_price')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
oneBed_df.head()
# Out:
#      BedSize  Year Month  Apartment_rent Shift_Year Shift_Month  \
# 84  1Bedroom  2011    01          1050.0       2011          01
# 85  1Bedroom  2011    02          1091.5       2011          02
# 86  1Bedroom  2011    03          1035.0       2011          03
# 87  1Bedroom  2011    04          1072.5       2011          04
# 88  1Bedroom  2011    05          1100.0       2011          05
#
#     Zillow_Housing_price Search_Count_SeattleRent Search_Count_SeattleHousing  \
# 84              370800.0                       48                          27
# 85              376000.0                       46                          32
# 86              382800.0                       37                          33
# 87              373500.0                       33                          22
# 88              368400.0                       33                          25
#
#    Search_Count_seattleApartment    ...      New Listings Yoy  \
# 84                            22    ...                   NaN
# 85                            24    ...                   NaN
# 86                            24    ...                   NaN
# 87                            16    ...                   NaN
# 88                            21    ...                   NaN
#
#    Number of Records Price Drops Price Drops Mom Price Drops Yoy  \
# 84               NaN         NaN             NaN             NaN
# 85               NaN         NaN             NaN             NaN
# 86               NaN         NaN             NaN             NaN
# 87               NaN         NaN             NaN             NaN
# 88               NaN         NaN             NaN             NaN
#
#    Sold Above List Sold Above List Mom Sold Above List Yoy       Date  \
# 84             NaN                 NaN                 NaN 2011-01-01
# 85             NaN                 NaN                 NaN 2011-02-01
# 86             NaN                 NaN                 NaN 2011-03-01
# 87             NaN                 NaN                 NaN 2011-04-01
# 88             NaN                 NaN                 NaN 2011-05-01
#
#     log_price
# 84   6.956545
# 85   6.995308
# 86   6.942157
# 87   6.977748
# 88   7.003065
#
# [5 rows x 49 columns]

# %%
twoBed_df.plot.line(x='Year', y='Apartment_rent')

# %%
twoBed_df['Apartment_rent'].hist()

# %%
merge_housing_dropNa = merge_housing.dropna()
merge_housing_dropNa.Search_Count_SeattleRent = merge_housing_dropNa.Search_Count_SeattleRent.astype(int)
merge_housing_dropNa.Search_Count_SeattleHousing = merge_housing_dropNa.Search_Count_SeattleHousing.astype(int)
merge_housing_dropNa.Search_Count_seattleApartment = merge_housing_dropNa.Search_Count_seattleApartment.astype(int)

merge_housing_dropNa.dtypes

# %%
# Plot all of the variable-to-variable relations as scatterplots
#pd.scatter_matrix(merge_housing_dropNa.iloc[:, -5:-1], figsize=(12,8), s=10);

# %%
#merge_housing_dropNa.dtypes

# %%
studio_index = studio_df.set_index('Date')
studio_index.head()
y = studio_index.Apartment_rent
y.index.name = 'Date'
y.head()

# %%
ax = y.plot();
ax.set_ylabel('# Rent');

# %%
y.loc['2017-01-01':'2017-12-01'].plot();

# %%
known = y.loc['2012-01-01':'2017-12-01']
unknown = y.loc['2018-01-01':'2018-12-01']
to_predict = y.loc['2018-01-01':'2018-12-01']

fig, ax = plt.subplots();
known.plot(ax=ax, c='c', marker='o', zorder=3);
unknown.plot(ax=ax, c='grey', alpha=0.5);
to_predict.plot(ax=ax, c='r', marker='o', markersize=16,
                linestyle='');

ax.legend(['known', 'future', 'value to predict']);
ax.set_ylabel('# rent');

# %% [markdown]
# # Delete
