# %%
# Python 2 & 3 Compatibility
from __future__ import print_function, division

# Necessary imports
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
import os
import pickle
# %matplotlib inline
from datetime import datetime
from dateutil.parser import parse
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
with open("apartment_sale.pkl", 'rb') as picklefile: 
    zillow_apartment_df = pickle.load(picklefile)
zillow_apartment_df.head()
# Out:
#    RegionName State    Metro CountyName SizeRank BedSize  Year Month  Amount
# 18    Seattle    WA  Seattle       King       19  Studio  2011    03  1097.5
# 18    Seattle    WA  Seattle       King       19  Studio  2011    04  1095.0
# 18    Seattle    WA  Seattle       King       19  Studio  2011    05  1025.0
# 18    Seattle    WA  Seattle       King       19  Studio  2011    06   995.0
# 18    Seattle    WA  Seattle       King       19  Studio  2011    07  1000.0

# %%
studio_df = zillow_apartment_df.loc[zillow_apartment_df['BedSize'] == 'Studio']
studio_df['Year'].value_counts()
# Out:
# 2015    12
# 2016    12
# 2014    12
# 2013    12
# 2017    12
# 2012    12
# 2011    10
# 2018     2
# Name: Year, dtype: int64

# %%
zillow_apartment_df.shape
# Out:
# (302, 9)

# %%
with open("google_trend.pkl", 'rb') as picklefile: 
    google_trend_df = pickle.load(picklefile)

google_trend_df.head()
k = google_trend_df.groupby(['Year', 'Month']).count()

# %%
google_trend_df ['Date'] = pd.to_datetime((google_trend_df['Year'] + '-' + google_trend_df['Month']+ '-01') ,format='%Y-%m-%d')
google_trend_df.shape
# Out:
# (516, 5)

# %%
date_shift_six_month_df = google_trend_df.Date+   pd.offsets.DateOffset(months=-6)
google_trend_df ['Shift_Year'] = date_shift_six_month_df.dt.year
google_trend_df ['Shift_Month'] = date_shift_six_month_df.dt.month.map("{:02}".format)
google_trend_df.shape
# Out:
# (516, 7)

# %%
google_trend_df_SeattleRent = google_trend_df.loc[google_trend_df['Term'] == 'SeattleRent']
google_trend_df_SeattleRent.rename(columns={"Amount": "Search_Count_SeattleRent"}, inplace=True)
google_trend_df_SeattleRent = google_trend_df_SeattleRent.drop(['Term', 'Year','Month', 'Date'], 1)

google_trend_df_SeattleHousing = google_trend_df.loc[google_trend_df['Term'] == 'SeattleHousing']
google_trend_df_SeattleHousing.rename(columns={"Amount": "Search_Count_SeattleHousing"}, inplace=True)
google_trend_df_SeattleHousing = google_trend_df_SeattleHousing.drop(['Term', 'Year','Month', 'Date'], 1)

google_trend_df_seattleApartment = google_trend_df.loc[google_trend_df['Term'] == 'seattleApartment']
google_trend_df_seattleApartment.rename(columns={"Amount": "Search_Count_seattleApartment"}, inplace=True)
google_trend_df_seattleApartment = google_trend_df_seattleApartment.drop(['Term', 'Year','Month', 'Date'], 1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
google_trend_df_SeattleRent.tail()
# Out:
#     Search_Count_SeattleRent  Shift_Year Shift_Month
# 167                       31        2017          06
# 168                       39        2017          07
# 169                       38        2017          08
# 170                       38        2017          09
# 171                       40        2017          10

# %%
with open("zillow_housing.pkl", 'rb') as picklefile: 
    zillow_housing_df = pickle.load(picklefile)
zillow_housing_df.head()
# Out:
#     RegionID RegionName   StateName SizeRank  Year Month    Amount
# 17   16037.0    Seattle  Washington       18  2008    03  421300.0
# 17   16037.0    Seattle  Washington       18  2008    04  424000.0
# 17   16037.0    Seattle  Washington       18  2008    05  426000.0
# 17   16037.0    Seattle  Washington       18  2008    06  422900.0
# 17   16037.0    Seattle  Washington       18  2008    07  414400.0

# %%
zillow_housing_df ['Date'] = pd.to_datetime((zillow_housing_df['Year'] + '-' + zillow_housing_df['Month']+ '-01') ,format='%Y-%m-%d')
zillow_housing_df_shift_six_month_df = zillow_housing_df.Date+   pd.offsets.DateOffset(months=-6)
zillow_housing_df ['Shift_Year'] = zillow_housing_df_shift_six_month_df.dt.year.astype(str)
zillow_housing_df ['Shift_Month'] = zillow_housing_df_shift_six_month_df.dt.month.map("{:02}".format)
zillow_housing_df = zillow_housing_df.drop(['RegionID','RegionName','StateName','SizeRank','Year','Month', 'Date'], 1)


zillow_housing_df.head()
# Out:
#       Amount Shift_Year Shift_Month
# 17  421300.0       2007          09
# 17  424000.0       2007          10
# 17  426000.0       2007          11
# 17  422900.0       2007          12
# 17  414400.0       2008          01

# %%
zillow_apartment_df['Shift_Year'] = zillow_apartment_df['Year'].astype(str)
zillow_apartment_df['Shift_Month'] = zillow_apartment_df['Month'].astype(str)

# %%
merge_housing = pd.merge(zillow_apartment_df, zillow_housing_df, on=['Shift_Year', 'Shift_Month'], how='left')
merge_housing = merge_housing.rename(columns={'Amount_y':'Zillow_Housing_price'})
merge_housing = merge_housing.rename(columns={'Amount_x':'Apartment_rent'})


merge_housing.shape
# Out:
# (302, 12)

# %%
google_trend_df_SeattleRent['Shift_Year'] = google_trend_df_SeattleRent['Shift_Year'].astype(str)
google_trend_df_SeattleRent['Shift_Month'] = google_trend_df_SeattleRent['Shift_Month'].astype(str)
k = google_trend_df_SeattleRent.groupby(['Shift_Year', 'Shift_Month']).count()
k.head(1)
# Out:
#                         Search_Count_SeattleRent
# Shift_Year Shift_Month
# 2003       07                                  1

# %%
merge_housing = merge_housing.drop(['RegionName','State','Metro', 'CountyName', 'SizeRank'], 1)

merge_housing  = pd.merge(merge_housing, google_trend_df_SeattleRent, on=['Shift_Year', 'Shift_Month'], how='left')
merge_housing.shape
# Out:
# (302, 8)

# %%
google_trend_df_SeattleHousing['Shift_Year'] = google_trend_df_SeattleHousing['Shift_Year'].astype(str)
google_trend_df_SeattleHousing['Shift_Month'] = google_trend_df_SeattleHousing['Shift_Month'].astype(str)

merge_housing  = pd.merge(merge_housing, google_trend_df_SeattleHousing, on=['Shift_Year', 'Shift_Month'], how='left')

google_trend_df_seattleApartment['Shift_Year'] = google_trend_df_seattleApartment['Shift_Year'].astype(str)
google_trend_df_seattleApartment['Shift_Month'] = google_trend_df_seattleApartment['Shift_Month'].astype(str)

merge_housing  = pd.merge(merge_housing, google_trend_df_seattleApartment, on=['Shift_Year', 'Shift_Month'], how='left')
merge_housing.head()
# Out:
#   BedSize  Year Month  Apartment_rent Shift_Year Shift_Month  \
# 0  Studio  2011    03          1097.5       2011          03
# 1  Studio  2011    04          1095.0       2011          04
# 2  Studio  2011    05          1025.0       2011          05
# 3  Studio  2011    06           995.0       2011          06
# 4  Studio  2011    07          1000.0       2011          07
#
#    Zillow_Housing_price Search_Count_SeattleRent Search_Count_SeattleHousing  \
# 0              382800.0                       37                          33
# 1              373500.0                       33                          22
# 2              368400.0                       33                          25
# 3              359300.0                       27                          23
# 4              365300.0                       36                          25
#
#   Search_Count_seattleApartment
# 0                            24
# 1                            16
# 2                            21
# 3                            19
# 4                            22

# %%
redfin_housing=pd.read_csv('data/House/Redfin_Seattle_All.csv')
redfin_housing['Region Type'].value_counts()
redfin_housing.head()
# Out:
#       City  Measure Display Period Begin  Period End    Property Type  \
# 0  Seattle              NaN     1/1/2012   1/31/2012  All Residential
# 1  Seattle              NaN     5/1/2015   5/31/2015  All Residential
# 2  Seattle              NaN     7/1/2017   7/31/2017  All Residential
# 3  Seattle              NaN    11/1/2014  11/30/2014  All Residential
# 4  Seattle              NaN     7/1/2016   7/31/2016  All Residential
#
#         Region Region Type       State State Code  Table Id  \
# 0  Seattle, WA       place  Washington         WA     16163
# 1  Seattle, WA       place  Washington         WA     16163
# 2  Seattle, WA       place  Washington         WA     16163
# 3  Seattle, WA       place  Washington         WA     16163
# 4  Seattle, WA       place  Washington         WA     16163
#
#           ...         New Listings Mom  New Listings Yoy Number of Records  \
# 0         ...                   67.50%           -16.20%                 1
# 1         ...                   -0.90%            -1.60%                 1
# 2         ...                  -12.00%            -8.10%                 1
# 3         ...                  -39.90%            -1.20%                 1
# 4         ...                   -3.20%            11.40%                 1
#
#   Period Duration Price Drops Price Drops Mom Price Drops Yoy Sold Above List  \
# 0              30    0.286394        0.082724       -0.006008        0.162996
# 1              30    0.197441       -0.020950       -0.079781        0.561572
# 2              30    0.245077       -0.009731       -0.005338        0.595837
# 3              30    0.276562       -0.078092       -0.018133        0.277987
# 4              30    0.250415       -0.017460        0.019002        0.510056
#
#   Sold Above List Mom Sold Above List Yoy
# 0           -0.008754            0.059369
# 1           -0.002885            0.121801
# 2           -0.055433            0.085781
# 3           -0.051151           -0.004197
# 4           -0.026529            0.023713
#
# [5 rows x 49 columns]

# %%
redfin_housing = redfin_housing.drop(['City','Measure Display','Period End','State','State Code', 'Table Id', 'Property Type','Period Duration', 'Region Type', 'Region', 'Worksheet Filter'],1)
redfin_housing.head()
# Out:
#   Period Begin  Avg Sale To List Avg Sale To List Mom Avg Sale To List Yoy  \
# 0     1/1/2012          0.969093               -0.20%                0.90%
# 1     5/1/2015          1.036981                0.30%                2.30%
# 2     7/1/2017          1.055992               -1.70%                2.20%
# 3    11/1/2014          0.996997               -0.30%                0.30%
# 4     7/1/2016          1.034185               -1.00%                0.10%
#
#   Homes Sold Homes Sold Mom Homes Sold Yoy Inventory Inventory Mom  \
# 0        454        -27.10%         17.60%     2,102        -3.60%
# 1      1,145          5.40%          9.50%     1,094         4.80%
# 2      1,158        -10.90%         -6.90%       914         9.90%
# 3        796        -22.90%          3.50%     1,280       -18.90%
# 4      1,244        -13.30%         -5.60%     1,206        15.00%
#
#   Inventory Yoy         ...           New Listings  New Listings Mom  \
# 0       -28.70%         ...                    655            67.50%
# 1       -26.90%         ...                  1,394            -0.90%
# 2       -24.20%         ...                  1,233           -12.00%
# 3       -16.20%         ...                    593           -39.90%
# 4        12.10%         ...                  1,342            -3.20%
#
#    New Listings Yoy  Number of Records  Price Drops  Price Drops Mom  \
# 0           -16.20%                  1     0.286394         0.082724
# 1            -1.60%                  1     0.197441        -0.020950
# 2            -8.10%                  1     0.245077        -0.009731
# 3            -1.20%                  1     0.276562        -0.078092
# 4            11.40%                  1     0.250415        -0.017460
#
#   Price Drops Yoy  Sold Above List  Sold Above List Mom  Sold Above List Yoy
# 0       -0.006008         0.162996            -0.008754             0.059369
# 1       -0.079781         0.561572            -0.002885             0.121801
# 2       -0.005338         0.595837            -0.055433             0.085781
# 3       -0.018133         0.277987            -0.051151            -0.004197
# 4        0.019002         0.510056            -0.026529             0.023713
#
# [5 rows x 38 columns]

# %%
redfin_housing ['Date'] = pd.to_datetime((redfin_housing['Period Begin']) ,format='%m/%d/%Y')
redfin_housing_shif = redfin_housing.Date+   pd.offsets.DateOffset(months=-6)
redfin_housing ['Shift_Year'] = redfin_housing_shif.dt.year.astype(str)
redfin_housing ['Shift_Month'] = redfin_housing_shif.dt.month.map("{:02}".format)
redfin_housing = redfin_housing.drop(['Period Begin', 'Date'], 1)


redfin_housing.head()
# Out:
#    Avg Sale To List Avg Sale To List Mom Avg Sale To List Yoy Homes Sold  \
# 0          0.969093               -0.20%                0.90%        454
# 1          1.036981                0.30%                2.30%      1,145
# 2          1.055992               -1.70%                2.20%      1,158
# 3          0.996997               -0.30%                0.30%        796
# 4          1.034185               -1.00%                0.10%      1,244
#
#   Homes Sold Mom Homes Sold Yoy Inventory Inventory Mom Inventory Yoy  \
# 0        -27.10%         17.60%     2,102        -3.60%       -28.70%
# 1          5.40%          9.50%     1,094         4.80%       -26.90%
# 2        -10.90%         -6.90%       914         9.90%       -24.20%
# 3        -22.90%          3.50%     1,280       -18.90%       -16.20%
# 4        -13.30%         -5.60%     1,206        15.00%        12.10%
#
#    Median Dom     ...       New Listings Yoy  Number of Records  Price Drops  \
# 0          59     ...                -16.20%                  1     0.286394
# 1           7     ...                 -1.60%                  1     0.197441
# 2           8     ...                 -8.10%                  1     0.245077
# 3          20     ...                 -1.20%                  1     0.276562
# 4           8     ...                 11.40%                  1     0.250415
#
#    Price Drops Mom  Price Drops Yoy Sold Above List  Sold Above List Mom  \
# 0         0.082724        -0.006008        0.162996            -0.008754
# 1        -0.020950        -0.079781        0.561572            -0.002885
# 2        -0.009731        -0.005338        0.595837            -0.055433
# 3        -0.078092        -0.018133        0.277987            -0.051151
# 4        -0.017460         0.019002        0.510056            -0.026529
#
#    Sold Above List Yoy  Shift_Year  Shift_Month
# 0             0.059369        2011           07
# 1             0.121801        2014           11
# 2             0.085781        2017           01
# 3            -0.004197        2014           05
# 4             0.023713        2016           01
#
# [5 rows x 39 columns]

# %%
merge_housing  = pd.merge(merge_housing, redfin_housing, on=['Shift_Year', 'Shift_Month'], how='left')
merge_housing.head()
# Out:
#   BedSize  Year Month  Apartment_rent Shift_Year Shift_Month  \
# 0  Studio  2011    03          1097.5       2011          03
# 1  Studio  2011    04          1095.0       2011          04
# 2  Studio  2011    05          1025.0       2011          05
# 3  Studio  2011    06           995.0       2011          06
# 4  Studio  2011    07          1000.0       2011          07
#
#    Zillow_Housing_price Search_Count_SeattleRent Search_Count_SeattleHousing  \
# 0              382800.0                       37                          33
# 1              373500.0                       33                          22
# 2              368400.0                       33                          25
# 3              359300.0                       27                          23
# 4              365300.0                       36                          25
#
#   Search_Count_seattleApartment         ...           New Listings  \
# 0                            24         ...                    NaN
# 1                            16         ...                    NaN
# 2                            21         ...                    NaN
# 3                            19         ...                    NaN
# 4                            22         ...                    655
#
#   New Listings Mom New Listings Yoy Number of Records Price Drops  \
# 0              NaN              NaN               NaN         NaN
# 1              NaN              NaN               NaN         NaN
# 2              NaN              NaN               NaN         NaN
# 3              NaN              NaN               NaN         NaN
# 4           67.50%          -16.20%               1.0    0.286394
#
#   Price Drops Mom Price Drops Yoy Sold Above List Sold Above List Mom  \
# 0             NaN             NaN             NaN                 NaN
# 1             NaN             NaN             NaN                 NaN
# 2             NaN             NaN             NaN                 NaN
# 3             NaN             NaN             NaN                 NaN
# 4        0.082724       -0.006008        0.162996           -0.008754
#
#    Sold Above List Yoy
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4             0.059369
#
# [5 rows x 47 columns]

# %%
merge_housing ['Date'] = pd.to_datetime((merge_housing['Year'] + '-' + merge_housing['Month']+ '-01') ,format='%Y-%m-%d')
merge_housing ['Date'].head()
# Out:
# 0   2011-03-01
# 1   2011-04-01
# 2   2011-05-01
# 3   2011-06-01
# 4   2011-07-01
# Name: Date, dtype: datetime64[ns]

# %%
with open('all_data.pkl', 'wb') as picklefile:
    pickle.dump(merge_housing, picklefile)

# %%
with open("all_data.pkl", 'rb') as picklefile: 
    my_old_data = pickle.load(picklefile)
my_old_data.head()
# Out:
#   BedSize  Year Month  Apartment_rent Shift_Year Shift_Month  \
# 0  Studio  2011    03          1097.5       2011          03
# 1  Studio  2011    04          1095.0       2011          04
# 2  Studio  2011    05          1025.0       2011          05
# 3  Studio  2011    06           995.0       2011          06
# 4  Studio  2011    07          1000.0       2011          07
#
#    Zillow_Housing_price Search_Count_SeattleRent Search_Count_SeattleHousing  \
# 0              382800.0                       37                          33
# 1              373500.0                       33                          22
# 2              368400.0                       33                          25
# 3              359300.0                       27                          23
# 4              365300.0                       36                          25
#
#   Search_Count_seattleApartment    ...      New Listings Mom New Listings Yoy  \
# 0                            24    ...                   NaN              NaN
# 1                            16    ...                   NaN              NaN
# 2                            21    ...                   NaN              NaN
# 3                            19    ...                   NaN              NaN
# 4                            22    ...                67.50%          -16.20%
#
#   Number of Records Price Drops Price Drops Mom Price Drops Yoy  \
# 0               NaN         NaN             NaN             NaN
# 1               NaN         NaN             NaN             NaN
# 2               NaN         NaN             NaN             NaN
# 3               NaN         NaN             NaN             NaN
# 4               1.0    0.286394        0.082724       -0.006008
#
#   Sold Above List Sold Above List Mom Sold Above List Yoy       Date
# 0             NaN                 NaN                 NaN 2011-03-01
# 1             NaN                 NaN                 NaN 2011-04-01
# 2             NaN                 NaN                 NaN 2011-05-01
# 3             NaN                 NaN                 NaN 2011-06-01
# 4        0.162996           -0.008754            0.059369 2011-07-01
#
# [5 rows x 48 columns]
