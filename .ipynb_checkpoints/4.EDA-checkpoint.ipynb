# %%
# Python 2 & 3 Compatibility
from __future__ import print_function, division

# Necessary imports
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
import os
import pickle
# %matplotlib inline
from datetime import datetime
from dateutil.parser import parse

# %%
with open("all_clean_data.pkl", 'rb') as picklefile: 
    merge_housing = pickle.load(picklefile)
merge_housing.head()

# %%
merge_housing=merge_housing.dropna()

# %%
studio_df = merge_housing.loc[merge_housing['BedSize'] == 'Studio']
oneBed_df = merge_housing.loc[merge_housing['BedSize'] == '1Bedroom']
twoBed_df = merge_housing.loc[merge_housing['BedSize'] == '2Bedroom']

# %%
sns.distplot(merge_housing.Apartment_rent)

# %%
plt.subplots(figsize=(18.5, 10.5))
ax = sns.swarmplot(x=merge_housing['BedSize'], y=merge_housing['Apartment_rent'], data=merge_housing)
ax.set_ylabel('Apartment Rent', fontsize=16);
ax.set_xlabel('Bed Size', fontsize=18)
fig = ax.get_figure()
fig.savefig("swarmplot_Apartment_BedSize.png")

# %%
merge_housing.dtypes

# %%
selectColumns = ['Year','Month','Zillow_Housing_price'
                                     , 'Search_Count_SeattleHousing'
                                     , 'Search_Count_seattleApartment'
                                     , 'HomesSold'
                                     , 'MedianSalePrice'
                                     , 'Inventory'
                                     , 'SoldAboveListYoy'
                                     , 'PriceDropsMom'
                                     , 'target_Apartment_rent'
                                    ]]

# %%
selected_col = merge_housing.loc[:, selectColumns]

# %%
fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches

ax = sns.heatmap(selected_col.corr(),cmap='YlGnBu', vmin=0)
fig = ax.get_figure()
fig.savefig("heatmap.png")

# %%
g = sns.pairplot(selected_col)

# %%
merge_housing.plot.line(x='Date', y='Zillow_Housing_price')

# %%
sns.distplot(merge_housing.Zillow_Housing_price.dropna())

# %%
# Let's now look at Distribution of Age and Survived
# Now look at survived data
g = sns.FacetGrid(merge_housing, col='BedSize')
g.map(plt.scatter, 'Year', "Apartment_rent")

# %%
merge_housing['Year'].value_counts()
# Out:
# 2017    47
# 2016    46
# 2015    36
# 2014    36
# 2013    36
# 2012    36
# 2011    18
# Name: Year, dtype: int64

# %%
merge_housing['BedSize'].value_counts()
# Out:
# 3Bedroom          74
# Studio            74
# 1Bedroom          74
# 5BedroomOrMore    14
# 2Bedroom          12
# 4Bedroom           7
# Name: BedSize, dtype: int64

# %%
#df_apartment_bedSize = pd.get_dummies(merge_housing['BedSize'])
#zillow_apartment_df_new = pd.concat([merge_housing, df_apartment_bedSize], axis=1)

# %%
# Get Average
zillow_apartment_grouped_df = merge_housing
zillow_apartment_grouped_df.groupby(['BedSize', 'Year', 'Month'], as_index=False)['Apartment_rent'].agg('mean')
zillow_apartment_grouped_df.head()
# Out:
#   BedSize  Year  Month  Apartment_rent Shift_Year Shift_Month  \
# 4  Studio  2011      7          1000.0       2011          07
# 5  Studio  2011      8          1000.0       2011          08
# 6  Studio  2011      9          1075.0       2011          09
# 7  Studio  2011     10           995.0       2011          10
# 8  Studio  2011     11           865.0       2011          11
#
#    Zillow_Housing_price  Search_Count_SeattleRent  \
# 4              365300.0                        36
# 5              367900.0                        36
# 6              381900.0                        38
# 7              393600.0                        38
# 8              400700.0                        46
#
#    Search_Count_SeattleHousing  Search_Count_seattleApartment  \
# 4                           25                             22
# 5                           24                             22
# 6                           28                             22
# 7                           29                             28
# 8                           26                             25
#
#            ...            NewListingsYoy  NumberofRecords  PriceDrops  \
# 4          ...                     -16.2              1.0    0.286394
# 5          ...                     -11.2              1.0    0.289133
# 6          ...                      -6.4              1.0    0.282218
# 7          ...                      -8.1              1.0    0.262083
# 8          ...                       4.8              1.0    0.259186
#
#    PriceDropsMom  PriceDropsYoy  SoldAboveList  SoldAboveListMom  \
# 4       0.082724      -0.006008       0.162996         -0.008754
# 5       0.002739       0.019233       0.167315          0.004320
# 6      -0.006915      -0.040034       0.255848          0.088533
# 7      -0.020135      -0.028809       0.270305          0.014457
# 8      -0.002897      -0.039458       0.292494          0.022190
#
#    SoldAboveListYoy       Date  target_Apartment_rent
# 4          0.059369 2011-07-01                 1000.0
# 5          0.038875 2011-08-01                 1000.0
# 6          0.130313 2011-09-01                 1075.0
# 7          0.104366 2011-10-01                  995.0
# 8          0.136814 2011-11-01                  865.0
#
# [5 rows x 49 columns]

# %%
merge_housing['Apartment_rent'].hist()

# %%
studio_df['Year'].value_counts()
# Out:
# 2016    12
# 2015    12
# 2014    12
# 2013    12
# 2012    12
# 2017     8
# 2011     6
# Name: Year, dtype: int64

# %%
studio_df.head()
# Out:
#   BedSize  Year  Month  Apartment_rent Shift_Year Shift_Month  \
# 4  Studio  2011      7          1000.0       2011          07
# 5  Studio  2011      8          1000.0       2011          08
# 6  Studio  2011      9          1075.0       2011          09
# 7  Studio  2011     10           995.0       2011          10
# 8  Studio  2011     11           865.0       2011          11
#
#    Zillow_Housing_price  Search_Count_SeattleRent  \
# 4              365300.0                        36
# 5              367900.0                        36
# 6              381900.0                        38
# 7              393600.0                        38
# 8              400700.0                        46
#
#    Search_Count_SeattleHousing  Search_Count_seattleApartment  \
# 4                           25                             22
# 5                           24                             22
# 6                           28                             22
# 7                           29                             28
# 8                           26                             25
#
#            ...            NewListingsYoy  NumberofRecords  PriceDrops  \
# 4          ...                     -16.2              1.0    0.286394
# 5          ...                     -11.2              1.0    0.289133
# 6          ...                      -6.4              1.0    0.282218
# 7          ...                      -8.1              1.0    0.262083
# 8          ...                       4.8              1.0    0.259186
#
#    PriceDropsMom  PriceDropsYoy  SoldAboveList  SoldAboveListMom  \
# 4       0.082724      -0.006008       0.162996         -0.008754
# 5       0.002739       0.019233       0.167315          0.004320
# 6      -0.006915      -0.040034       0.255848          0.088533
# 7      -0.020135      -0.028809       0.270305          0.014457
# 8      -0.002897      -0.039458       0.292494          0.022190
#
#    SoldAboveListYoy       Date  target_Apartment_rent
# 4          0.059369 2011-07-01                 1000.0
# 5          0.038875 2011-08-01                 1000.0
# 6          0.130313 2011-09-01                 1075.0
# 7          0.104366 2011-10-01                  995.0
# 8          0.136814 2011-11-01                  865.0
#
# [5 rows x 49 columns]

# %%
g = sns.pairplot(studio_df.loc[:, selectColumns])

# %%
studio_df.plot(x='Date', y='Apartment_rent')

# %%
studio_df[studio_df.Apartment_rent < 1200]
# Out:
#    BedSize  Year  Month  Apartment_rent Shift_Year Shift_Month  \
# 4   Studio  2011      7          1000.0       2011          07
# 5   Studio  2011      8          1000.0       2011          08
# 6   Studio  2011      9          1075.0       2011          09
# 7   Studio  2011     10           995.0       2011          10
# 8   Studio  2011     11           865.0       2011          11
# 9   Studio  2011     12           902.0       2011          12
# 10  Studio  2012      1           897.0       2012          01
# 11  Studio  2012      2           900.0       2012          02
# 12  Studio  2012      3          1025.0       2012          03
# 13  Studio  2012      4          1060.0       2012          04
# 14  Studio  2012      5          1060.0       2012          05
# 15  Studio  2012      6          1072.5       2012          06
# 16  Studio  2012      7          1080.0       2012          07
# 17  Studio  2012      8          1095.0       2012          08
# 18  Studio  2012      9          1150.0       2012          09
# 19  Studio  2012     10          1195.0       2012          10
# 20  Studio  2012     11          1195.0       2012          11
# 21  Studio  2012     12          1150.0       2012          12
# 22  Studio  2013      1          1140.0       2013          01
# 23  Studio  2013      2          1147.5       2013          02
# 26  Studio  2013      5          1140.0       2013          05
# 27  Studio  2013      6          1150.0       2013          06
# 28  Studio  2013      7          1188.0       2013          07
# 29  Studio  2013      8          1199.0       2013          08
# 31  Studio  2013     10          1180.0       2013          10
# 36  Studio  2014      3          1195.0       2014          03
#
#     Zillow_Housing_price  Search_Count_SeattleRent  \
# 4               365300.0                        36
# 5               367900.0                        36
# 6               381900.0                        38
# 7               393600.0                        38
# 8               400700.0                        46
# 9               395100.0                        45
# 10              390600.0                        50
# 11              392100.0                        47
# 12              400800.0                        37
# 13              400300.0                        27
# 14              406000.0                        30
# 15              405800.0                        31
# 16              406600.0                        39
# 17              412600.0                        37
# 18              418300.0                        38
# 19              423300.0                        39
# 20              419900.0                        39
# 21              415600.0                        43
# 22              420000.0                        46
# 23              421300.0                        43
# 26              427300.0                        30
# 27              427200.0                        29
# 28              430600.0                        40
# 29              435300.0                        37
# 31              424600.0                        40
# 36              444900.0                        41
#
#     Search_Count_SeattleHousing  Search_Count_seattleApartment  \
# 4                            25                             22
# 5                            24                             22
# 6                            28                             22
# 7                            29                             28
# 8                            26                             25
# 9                            29                             26
# 10                           31                             30
# 11                           25                             24
# 12                           26                             21
# 13                           25                             18
# 14                           21                             16
# 15                           23                             22
# 16                           25                             26
# 17                           35                             19
# 18                           27                             24
# 19                           31                             25
# 20                           28                             24
# 21                           30                             29
# 22                           23                             26
# 23                           29                             25
# 26                           20                             19
# 27                           21                             22
# 28                           25                             22
# 29                           23                             24
# 31                           27                             26
# 36                           27                             27
#
#             ...            NewListingsYoy  NumberofRecords  PriceDrops  \
# 4           ...                     -16.2              1.0    0.286394
# 5           ...                     -11.2              1.0    0.289133
# 6           ...                      -6.4              1.0    0.282218
# 7           ...                      -8.1              1.0    0.262083
# 8           ...                       4.8              1.0    0.259186
# 9           ...                      -6.8              1.0    0.279230
# 10          ...                       2.6              1.0    0.266467
# 11          ...                      -1.8              1.0    0.285342
# 12          ...                      13.1              1.0    0.281732
# 13          ...                       9.6              1.0    0.348890
# 14          ...                      -4.3              1.0    0.246684
# 15          ...                     -10.7              1.0    0.141647
# 16          ...                      10.8              1.0    0.212714
# 17          ...                      15.2              1.0    0.192969
# 18          ...                       8.6              1.0    0.245151
# 19          ...                      16.8              1.0    0.241528
# 20          ...                      31.3              1.0    0.264617
# 21          ...                      35.7              1.0    0.272079
# 22          ...                      34.7              1.0    0.295491
# 23          ...                      35.7              1.0    0.290030
# 26          ...                       6.8              1.0    0.294695
# 27          ...                       6.0              1.0    0.210196
# 28          ...                      13.2              1.0    0.249802
# 29          ...                      -7.4              1.0    0.237329
# 31          ...                       0.3              1.0    0.267216
# 36          ...                       1.5              1.0    0.330465
#
#     PriceDropsMom  PriceDropsYoy  SoldAboveList  SoldAboveListMom  \
# 4        0.082724      -0.006008       0.162996         -0.008754
# 5        0.002739       0.019233       0.167315          0.004320
# 6       -0.006915      -0.040034       0.255848          0.088533
# 7       -0.020135      -0.028809       0.270305          0.014457
# 8       -0.002897      -0.039458       0.292494          0.022190
# 9        0.020045      -0.042252       0.303323          0.010828
# 10      -0.012763      -0.049207       0.296429         -0.006894
# 11       0.018875      -0.030448       0.279461         -0.016967
# 12      -0.003609      -0.036479       0.311429          0.031967
# 13       0.067158       0.015557       0.260355         -0.051074
# 14      -0.102206      -0.062926       0.275457          0.015102
# 15      -0.105037      -0.062022       0.267143         -0.008314
# 16       0.071067      -0.073680       0.244318         -0.022825
# 17      -0.019745      -0.096164       0.339223          0.094904
# 18       0.052183      -0.037067       0.363415          0.024192
# 19      -0.003623      -0.020554       0.409664          0.046249
# 20       0.023089       0.005432       0.452999          0.043335
# 21       0.007462      -0.007151       0.431102         -0.021897
# 22       0.023412       0.029024       0.424084         -0.007019
# 23      -0.005461       0.004689       0.364376         -0.059708
# 26      -0.057995       0.048011       0.282185         -0.053840
# 27      -0.084499       0.068549       0.255348         -0.026837
# 28       0.039606       0.037088       0.277174          0.021826
# 29      -0.012473       0.044360       0.331746          0.054572
# 31       0.004972       0.025687       0.453044          0.048254
# 36       0.046292      -0.004673       0.318280         -0.029891
#
#     SoldAboveListYoy       Date  target_Apartment_rent
# 4           0.059369 2011-07-01                 1000.0
# 5           0.038875 2011-08-01                 1000.0
# 6           0.130313 2011-09-01                 1075.0
# 7           0.104366 2011-10-01                  995.0
# 8           0.136814 2011-11-01                  865.0
# 9           0.144919 2011-12-01                  902.0
# 10          0.118817 2012-01-01                  897.0
# 11          0.148671 2012-02-01                  900.0
# 12          0.160427 2012-03-01                 1025.0
# 13          0.074194 2012-04-01                 1060.0
# 14          0.082237 2012-05-01                 1060.0
# 15          0.095393 2012-06-01                 1072.5
# 16          0.081323 2012-07-01                 1080.0
# 17          0.171907 2012-08-01                 1095.0
# 18          0.107567 2012-09-01                 1150.0
# 19          0.139359 2012-10-01                 1195.0
# 20          0.160505 2012-11-01                 1195.0
# 21          0.127780 2012-12-01                 1150.0
# 22          0.127655 2013-01-01                 1140.0
# 23          0.084915 2013-02-01                 1147.5
# 26          0.006728 2013-05-01                 1140.0
# 27         -0.011795 2013-06-01                 1150.0
# 28          0.032856 2013-07-01                 1188.0
# 29         -0.007477 2013-08-01                 1199.0
# 31          0.043381 2013-10-01                 1180.0
# 36         -0.019923 2014-03-01                 1195.0
#
# [26 rows x 49 columns]

# %%
studio_df['Apartment_rent'].hist()

# %%
oneBed_df.plot.line(x='Date', y='Apartment_rent')

# %%
oneBed_df['Apartment_rent'].hist()

# %%
oneBed_df['log_price'] = np.log(oneBed_df['Apartment_rent'])
oneBed_df.plot.line(x='Date', y='log_price')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
oneBed_df.head()
# Out:
#      BedSize  Year  Month  Apartment_rent Shift_Year Shift_Month  \
# 90  1Bedroom  2011      7          1195.0       2011          07
# 91  1Bedroom  2011      8          1177.5       2011          08
# 92  1Bedroom  2011      9          1050.0       2011          09
# 93  1Bedroom  2011     10          1100.0       2011          10
# 94  1Bedroom  2011     11          1100.0       2011          11
#
#     Zillow_Housing_price  Search_Count_SeattleRent  \
# 90              365300.0                        36
# 91              367900.0                        36
# 92              381900.0                        38
# 93              393600.0                        38
# 94              400700.0                        46
#
#     Search_Count_SeattleHousing  Search_Count_seattleApartment    ...      \
# 90                           25                             22    ...
# 91                           24                             22    ...
# 92                           28                             22    ...
# 93                           29                             28    ...
# 94                           26                             25    ...
#
#     NumberofRecords  PriceDrops  PriceDropsMom  PriceDropsYoy  SoldAboveList  \
# 90              1.0    0.286394       0.082724      -0.006008       0.162996
# 91              1.0    0.289133       0.002739       0.019233       0.167315
# 92              1.0    0.282218      -0.006915      -0.040034       0.255848
# 93              1.0    0.262083      -0.020135      -0.028809       0.270305
# 94              1.0    0.259186      -0.002897      -0.039458       0.292494
#
#     SoldAboveListMom  SoldAboveListYoy       Date  target_Apartment_rent  \
# 90         -0.008754          0.059369 2011-07-01                 1195.0
# 91          0.004320          0.038875 2011-08-01                 1177.5
# 92          0.088533          0.130313 2011-09-01                 1050.0
# 93          0.014457          0.104366 2011-10-01                 1100.0
# 94          0.022190          0.136814 2011-11-01                 1100.0
#
#     log_price
# 90   7.085901
# 91   7.071149
# 92   6.956545
# 93   7.003065
# 94   7.003065
#
# [5 rows x 50 columns]

# %%
twoBed_df.plot.line(x='Date', y='Apartment_rent')

# %%
twoBed_df['Apartment_rent'].hist()

# %%
# Plot all of the variable-to-variable relations as scatterplots
#pd.scatter_matrix(merge_housing_dropNa.iloc[:, -5:-1], figsize=(12,8), s=10);

# %%
#merge_housing_dropNa.dtypes

# %%
studio_index = studio_df.set_index('Date')
studio_index.head()
y = studio_index.Apartment_rent
y.index.name = 'Date'
y.head()
# Out:
# Date
# 2011-07-01    1000.0
# 2011-08-01    1000.0
# 2011-09-01    1075.0
# 2011-10-01     995.0
# 2011-11-01     865.0
# Name: Apartment_rent, dtype: float64

# %%
ax = y.plot();
ax.set_ylabel('# Rent');

# %%
y.loc['2017-01-01':'2017-12-01'].plot();
