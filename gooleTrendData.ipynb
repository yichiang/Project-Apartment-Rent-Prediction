# %%
# Python 2 & 3 Compatibility
from __future__ import print_function, division

# Necessary imports
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
# %matplotlib inline

# %%
#import data
google_trend_term = ['rent', 'Seattlehousing', 'seattleApartment']
dataset = [None]*len(google_trend_term)
for index, term in enumerate(google_trend_term):
    print(term)
    dataset[index]=pd.read_csv('data/multiTimeline-{0}.csv'.format(term), header=None)
dataset
# Out:
# rent
# Seattlehousing
# seattleApartment
# [              0   1
#  0    2013-04-21  73
#  1    2013-04-28  79
#  2    2013-05-05  67
#  3    2013-05-12  68
#  4    2013-05-19  70
#  5    2013-05-26  65
#  6    2013-06-02  65
#  7    2013-06-09  71
#  8    2013-06-16  70
#  9    2013-06-23  78
#  10   2013-06-30  62
#  11   2013-07-07  75
#  12   2013-07-14  93
#  13   2013-07-21  78
#  14   2013-07-28  89
#  15   2013-08-04  86
#  16   2013-08-11  67
#  17   2013-08-18  63
#  18   2013-08-25  67
#  19   2013-09-01  68
#  20   2013-09-08  59
#  21   2013-09-15  53
#  22   2013-09-22  60
#  23   2013-09-29  54
#  24   2013-10-06  55
#  25   2013-10-13  54
#  26   2013-10-20  64
#  27   2013-10-27  42
#  28   2013-11-03  60
#  29   2013-11-10  55
#  ..          ...  ..
#  231  2017-09-24  57
#  232  2017-10-01  67
#  233  2017-10-08  53
#  234  2017-10-15  65
#  235  2017-10-22  54
#  236  2017-10-29  53
#  237  2017-11-05  67
#  238  2017-11-12  52
#  239  2017-11-19  49
# ...
